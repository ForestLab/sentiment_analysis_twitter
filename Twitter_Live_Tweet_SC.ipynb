# %%
import Model as s
from twitterapi import *
import json
# Out:
# 10664

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        tweet = all_data["text"]
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, "---", sentiment_value, "---", confidence)

        if confidence*100 >= 80:
            output = open("twitter-out.txt","a")
            output.write(sentiment_value)
            output.write('\n')
            output.close()
        return(True)

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=["obama"])
# Out:
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# It was under Obama and they can’t report. --- neg --- 1.0
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# RT @JudicialWatch: Judicial Watch released 224 pages of docs w/ ~1,000 summaries of Significant Incident Reports from HHS revealing Unaccom… --- pos --- 1.0
# My favourite Obama Anger Translator
#
# https://t.co/xQjeXCz4hu --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# @eugenegu @realDonaldTrump We let Obama act like a president way to long --- neg --- 1.0
# No one is saying trump wants our money, but his tax bill, has many middle class Americans paying more this year tha… https://t.co/PdaxiFvpXL --- neg --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# @susan_sundropsu @marklevinshow MUSLIMS of Somalia have taken over Minnesota thanks to Muslim Obama....these jihadist need to go --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @TomFitton: US says ex-intel official defected to Iran, revealed secrets. Why didn't Obama administration tell us about this in 2013?  h… --- pos --- 1.0
# @OneiDWilly1 @1952_rfp @TremendosNixon @WilliamBradyCoS @MSNBC @AOC When exactly did Obama say "you'd need a magic… https://t.co/NHVZTXiwGb --- neg --- 1.0
# Take that!!! --- neg --- 1.0
# @SethAbramson (POLL) How many hours a day would Fox talk about the story if this happened with Obama:
# - Obama gave… https://t.co/kxhOj8OGtu --- neg --- 1.0
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @winstonCovfefe: Canada's liberal PM @JustinTrudeau, aka the white version of Obama, said Sharia law is compatible with democracy 😡😡.
# RT… --- pos --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @JudicialWatch: A federal judge ruled that discovery can start in Hillary Clinton’s email scandal. Obama officials as well as Clinton ai… --- pos --- 1.0
# RT @johncardillo: USAF OSI agent converted to Islam on Iranian TV, then began spying for the IRGC.
#
# Obama’s FBI spoke with her but did noth… --- pos --- 1.0
# @bobby39151577 @brickyardd @M26HIL @jdforward @PeterBeinart Why was he arrested, what crime did he commit? Yet Obam… https://t.co/NwdiBieouz --- neg --- 1.0
# RT @RandyResist: The Obama Effect at the National Portrait
#
# When a guard was asked about her most memorable moments she had seen or heard.… --- pos --- 1.0
# Harry of @NewEarthLife and Keith of @UnCommLaw will join us at #MBKRising, a national convening celebrating the pro… https://t.co/aiOZAsxOjQ --- neg --- 1.0
# Según una encuesta, Michelle Obama es la mujer más admirada en Estados Unidos https://t.co/MYvJbehBJG --- pos --- 0.6
# @RandPaul Would you tell us if you voted Mr. Obama’s nominee Eric Holder. If yes why and if no why. Thanks --- pos --- 1.0
# @drewDevin2 @brightsided1029 @DrClassick @sheera63 @Ilhan Can you name one thing obama did that improved the lives… https://t.co/Y8PuArnTJ8 --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# RT @C_3C_3: Just so we are all clear...
#
# The Obama Administration illegally spied on Candidate Trump and later POTUS Trump under the lie of… --- neg --- 1.0
# @LOLGOP Maybe Trump should install a Presidential simulator, one that plays tutorial videos recorded by Barack Obama. --- neg --- 1.0
# RT @myserenity69: HOW LAZY IS #TRUMP??
#
# He tries to outdo #Obama by putting in a better golf simulator at the White House..
#
# TOO LAZY TO AC… --- neg --- 1.0
# RT @krassenstein: If you are wearing a MAGA hat I think be may need to read this several times:
#
# Hillary Clinton - Not arrested on Friday… --- neg --- 0.6
# RT @middleageriot: Donald Trump has made it a point of pride to do everything the exact opposite of Barack Obama.
#
# Has anyone told him that… --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @Uncle_Jimbo: OR
#
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @17Ivan71: @Thomas1774Paine Obama sold them a nuclear deal that would ensure they get nuclear weapons.  Where is the DOJ indictment of h… --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @colettey6: @charliekirk11 @luckdawg Reading this infuriates me bc how dare Democrats hate on @realDonaldTrump when they dont come any w… --- neg --- 1.0
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# RT @2runtherace: Obama to Claim Kenyan Citizenship As a Way to Escape!
#
# Black Panther - Representation of Power, ferocity, and Valor!
#
# Lear… --- neg --- 1.0
# RT @johncardillo: USAF OSI agent converted to Islam on Iranian TV, then began spying for the IRGC.
#
# Obama’s FBI spoke with her but did noth… --- pos --- 1.0
# RT @MentionMeT: Y’all, how is Carly pregnant when CarSon ain’t had sex since Obama was president? #GH --- neg --- 1.0
# @politico U.S. involvement in the war in Yemen started in 2015 under Obama's presidency - although this bill may ha… https://t.co/psHL8PNzL5 --- neg --- 1.0
# RT @ObamaFoundation: Harry of @NewEarthLife and Keith of @UnCommLaw will join us at #MBKRising, a national convening celebrating the progre… --- neg --- 1.0
# RT @fenrir_71: &lt;thread from hell&gt;
#
# I caught this @jonathanchait piece this morning, and it really lays bare some truths about the repubs th… --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# In an economical time when we should be laying down the debt.  Obama inherited a horrendous recession.  We had to s… https://t.co/21hMOIuevD --- neg --- 0.6
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @masquelibre: @Manuela_Alcala1 @FSucre @hramosallup Mi opinión es que contrataron a la firma de Thomas Shannon, quienes fueron abogados… --- pos --- 1.0
# RT @HeshmatAlavi: 22)
# So the Obama administration had the chance to prevent her from going... https://t.co/sL3Zhy6xVr --- neg --- 1.0
# RT @HeshmatAlavi: 16)
# "Federal authorities alleged Witt defected to #Iran in 2013 [the Obama years] &amp; provided Iran w/ the code name &amp; miss… --- neg --- 1.0
# Michelle Obama shares hilarious texts from her mom after Grammys https://t.co/54DqCPZXsq via @TODAYshow --- pos --- 1.0
# RT @patribotics: This account is disinformation. https://t.co/L1T82iIOJc --- neg --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @JesseKellyDC: The breadth of corruption under Barack Obama is truly staggering. Lucky for him our Guardians of Truth Media was madly in… --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# @drpauldorio @EmmaSegasture @thenation @johncusack @BernieSanders @BarackObama Obama’s fiscal policy was to the rig… https://t.co/jOIAe7awWo --- pos --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @TeaPainUSA: We desperately need another black president to get Republicans concerned about the national debt again!  #22TrillionNationa… --- neg --- 1.0
# RT @drawandstrike: If she defected to Iran and handed them all this damaging intelligence back in 2013, why am I only hearing about it now… --- neg --- 1.0
# RT @hellofromtiff: @polishprincessh @RL9631 Michelle, Here is the Deal, we love President Trump!!!!   Love him.  More every second of every… --- pos --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @portersure: Plagiarism runs in the family, 1st melanomia rips off Michelle https://t.co/O0jevfbqlF Trump steals Iconic Iranian photo fr… --- neg --- 1.0
# RT @Angelicanang: None of this was accidental.  Think about how many people Obozo put in potentially SENSITIVE positions, that have direct… --- neg --- 1.0
# Just when you think this idiot couldn't possibly say anything dumber he says this, Michelle Obama Should Run for Pr… https://t.co/O7QXEPFWhL --- neg --- 0.8
# RT @drawandstrike: I continue to be AMAZED at the amount of massive, epic, staggering intelligence failures that occurred while Obama was i… --- pos --- 1.0
# RT @Independent: David Cameron visited Saudi intelligence chief's son to tell him 'Obama is not serious in Syria' https://t.co/U6UFj13Ccw --- pos --- 1.0
# President Obama left a huge mess during his 8 years. --- neg --- 0.8
# RT @HeshmatAlavi: 23)
# This is probably another of Obama's marvelous achievements (!) that I should add to this long list of ...
# https://t.c… --- pos --- 1.0
# RT @HeshmatAlavi: 23)
# This is probably another of Obama's marvelous achievements (!) that I should add to this long list of ...
# https://t.c… --- pos --- 1.0
# RT @BusyElves: Obama and Clinton Worked together to overthrow our duly elected President.
# #LockThemUp #LockedUP?
# https://t.co/htMIOqFtUt --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# Michelle Obama Insists in Post-Grammys Text to Mom - 'I Am a Real Star'
# Michelle Obama is at home with those who l… https://t.co/HPJ1WO2Z10 --- neg --- 1.0
# RT @StevenBrettNeed: The administration are getting all the chess pieces in the right place. Barr,  judges, etc. Then, it's hammer time! #W… --- pos --- 0.6
# RT @Normani: MICHELLE OBAMA . that’s my tweet --- pos --- 1.0
# @Delilah399 @BrittMcHenry “Children in cages”, that started with Obama, genius. Nobody asked them to come here ille… https://t.co/4EKUbL7vhD --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @MarkSimoneNY: Fake News goes ballistic attacking President Trump for putting a $50,000 golf simulator in the White House, till they fin… --- neg --- 1.0
# @jimob131 @Fahrenthold @realDonaldTrump 1. So he didn't spend eight years on it. Pretty straightforward idea even f… https://t.co/1oIUtSUpvw --- pos --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @jlw8375309: The Russia Collusion Sham: More and More Evidence Leads Back to the Most Corrupt President Ever: Barack Hussein Obama https… --- neg --- 1.0
# Black Conservatives Debate Black Liberals on Trump, Obama, and American ... https://t.co/scSELA1cr6 via @YouTube --- neg --- 1.0
# RT @Kaiser1311: @lilisanch @OrlvndoA Esto huele raro. Eso de Maduro candidato cuando está entrever su nacionalidad y ajora contratan con el… --- pos --- 1.0
# RT @kylegriffin1: Michelle Obama, to an entirely captive crowd at The Grammys: "Music helps us share ourselves." Via CBS https://t.co/jQTfi… --- neg --- 1.0
# RT @T_S_P_O_O_K_Y: This is why we need a 100% review and scrub of all the FBI's foreign counterintelligence activities...this is not their… --- neg --- 0.8
# RT @NoahCRothman: Obama supported the Saudi effort to roll back an Iranian proxy driving toward the Gulf of Aden in mid-2015, as any presid… --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @ObamaFoundation: Harry of @NewEarthLife and Keith of @UnCommLaw will join us at #MBKRising, a national convening celebrating the progre… --- neg --- 1.0
# RT @Normani: MICHELLE OBAMA . that’s my tweet --- pos --- 1.0
# RT @drawandstrike: If she defected to Iran and handed them all this damaging intelligence back in 2013, why am I only hearing about it now… --- neg --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @MarkSimoneNY: Fake News goes ballistic attacking President Trump for putting a $50,000 golf simulator in the White House, till they fin… --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# RT @T_S_P_O_O_K_Y: All roads do lead to @AmbassadorRice and @BarackObama ... https://t.co/LllhX6IFgT --- neg --- 1.0
# RT @charliekirk11: Net worth before running for President:
#
# Trump family: $4.5 billion
# Obama - $3 million
# Clinton - $480,000
#
# Today:
#
# Trump… --- neg --- 0.8
# #WednesdayMotivation --- neg --- 1.0
# RT @ObamaFoundation: Harry of @NewEarthLife and Keith of @UnCommLaw will join us at #MBKRising, a national convening celebrating the progre… --- neg --- 1.0
# @freevoice22 @marklevinshow Obama did not was Netanyahu to win ...did that mean he conspired with the Palestinians… https://t.co/8lj8p0dNuX --- neg --- 1.0
# RT @Uncle_Jimbo: OR
#
# "@realDonaldTrump replaced the golf simulator installed by #Obama w/ one he paid for himself"
#
# Much different, and muc… --- pos --- 1.0
# RT @guypbenson: wait, had we heard about this Obama golf simulator before today? https://t.co/bvFEZVskDm --- neg --- 1.0
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# RT @drawandstrike: If she defected to Iran and handed them all this damaging intelligence back in 2013, why am I only hearing about it now… --- neg --- 1.0
# RT @Alyssafarah: Minor details: he just updated the system Obama had, he has yet to even use it, &amp; he paid for it out of pocket. https://t.… --- pos --- 0.6
# @YAppelbaum It amazing how you people on the  left are so stupid. Do you Obama shout had paid for basketball court? --- neg --- 1.0
# RT @drawandstrike: If she defected to Iran and handed them all this damaging intelligence back in 2013, why am I only hearing about it now… --- neg --- 1.0
# @lgsawyer @GOP @PressSec And in EIGHT years not one criminal charge! for President Obama. Wonder what his screening process was? --- pos --- 1.0
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\envs\DIP\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\envs\DIP\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~\Anaconda3\envs\DIP\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2837f0737c7b> in <module>
#      25
#      26 twitterStream = Stream(auth, listener())
# ---> 27 twitterStream.filter(track=["obama"])
#
# ~\Anaconda3\envs\DIP\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\envs\DIP\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~\Anaconda3\envs\DIP\lib\site-packages\tweepy\streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\envs\DIP\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~\Anaconda3\envs\DIP\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~\Anaconda3\envs\DIP\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     411             else:
#     412                 cache_content = False
# --> 413                 data = self._fp.read(amt)
#     414                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     415                     # Close the connection when no data is returned
#
# ~\Anaconda3\envs\DIP\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\envs\DIP\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\envs\DIP\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\envs\DIP\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\envs\DIP\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\envs\DIP\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\DIP\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     295                 raise
#     296         except OpenSSL.SSL.WantReadError:
# --> 297             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     298                 raise timeout('The read operation timed out')
#     299             else:
#
# ~\Anaconda3\envs\DIP\lib\site-packages\urllib3\util\wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~\Anaconda3\envs\DIP\lib\site-packages\urllib3\util\wait.py in select_wait_for_socket(sock, read, write, timeout)
#      84     # thing.)
#      85     fn = partial(select.select, rcheck, wcheck, wcheck)
# ---> 86     rready, wready, xready = _retry_on_intr(fn, timeout)
#      87     return bool(rready or wready or xready)
#      88
#
# ~\Anaconda3\envs\DIP\lib\site-packages\urllib3\util\wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# KeyboardInterrupt:
